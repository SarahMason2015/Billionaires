# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahMason2015/Billionaires/blob/main/BillionairesData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
import sklearn as skl
import tensorflow as tf

# %%
billion_df = pd.read_csv("resources/Dataset2Billionaires.csv")
billion_df.head()
# Out:
#    rank  finalWorth                personName         source  \
# 0     1  194752.748  Bernard Arnault & family           LVMH
# 1     2  193371.207                Jeff Bezos         Amazon
# 2     3  153245.292                 Elon Musk  Tesla, SpaceX
# 3     4  126812.953                Bill Gates      Microsoft
# 4     5  120055.498           Mark Zuckerberg       Facebook
#
#          industries countryOfCitizenship gender    lastName  estWorthPrev
# 0  Fashion & Retail               France      M     Arnault   194752.7476
# 1        Technology        United States      M       Bezos   193371.2075
# 2        Automotive        United States      M        Musk   153245.2917
# 3        Technology        United States      M       Gates   126812.9531
# 4        Technology        United States      M  Zuckerberg   120055.4980

# %%
billion_df.nunique()
# Out:
# rank                    2595
# finalWorth              2595
# personName              2736
# source                   965
# industries                18
# countryOfCitizenship      70
# gender                     2
# lastName                1738
# estWorthPrev            2597
# dtype: int64

# %%
billion_df['countryOfCitizenship'].value_counts()
# Out:
# United States           714
# China                   606
# India                   143
# Germany                 137
# Russia                  118
#                        ...
# Venezuela                 1
# Eswatini (Swaziland)      1
# Algeria                   1
# Liechtenstein             1
# Nepal                     1
# Name: countryOfCitizenship, Length: 70, dtype: int64

# %%
billion_df['lastName'].value_counts()
# Out:
# Wang         55
# Li           47
# Chen         42
# Zhang        37
# Wu           28
#              ..
# Iliev         1
# Jaipuria      1
# Milchan       1
# Kurtz         1
# Rafaelian     1
# Name: lastName, Length: 1738, dtype: int64

# %%
billion_df['industries'].value_counts()
# Out:
# Finance & Investments         362
# Technology                    353
# Manufacturing                 329
# Fashion & Retail              278
# Healthcare                    217
# Real Estate                   216
# Food & Beverage               215
# Diversified                   189
# Energy                        102
# Media & Entertainment          97
# Service                        75
# Metals & Mining                74
# Automotive                     69
# Construction & Engineering     46
# Logistics                      35
# Telecom                        32
# Gambling & Casinos             25
# Sports                         24
# Name: industries, dtype: int64

# %%
billion_df['finalWorth'].value_counts()
# Out:
# 2864.815    8
# 1000.000    6
# 1500.000    5
# 1184.378    4
# 8860.803    4
#            ..
# 3538.715    1
# 3534.529    1
# 3530.960    1
# 3530.765    1
# 100.000     1
# Name: finalWorth, Length: 2595, dtype: int64

# %%
billion_df['gender'].value_counts()
# Out:
# M    2413
# F     314
# Name: gender, dtype: int64

# %%
billion1_df = pd.read_csv("resources/billionaires.csv")
billion1_df.head()
# Out:
#              name  rank  year  company.founded        company.name  \
# 0      Bill Gates     1  1996             1975           Microsoft
# 1      Bill Gates     1  2001             1975           Microsoft
# 2      Bill Gates     1  2014             1975           Microsoft
# 3  Warren Buffett     2  1996             1962  Berkshire Hathaway
# 4  Warren Buffett     2  2001             1962  Berkshire Hathaway
#
#   company.relationship company.sector company.type  demographics.age  \
# 0              founder       Software          new                40
# 1              founder       Software          new                45
# 2              founder       Software          new                58
# 3              founder        Finance          new                65
# 4              founder        Finance          new                70
#
#   demographics.gender  ...  location.gdp location.region          wealth.type  \
# ...

# %%
billion1_df['name'].value_counts()
# Out:
# Bill Gates                    3
# Karl-Heinz Kipp               3
# Richard DeVos                 3
# Alberto Bailleres Gonzalez    3
# Lee Bass                      3
#                              ..
# Keiichiro Takahara            1
# Jamshyd Godrej                1
# George Bishop                 1
# Evan Williams                 1
# Zhu Wenchen                   1
# Name: name, Length: 2058, dtype: int64

# %%
billion1_df.nunique()
# Out:
# name                        2058
# rank                         468
# year                           3
# company.founded              178
# company.name                1577
# company.relationship          74
# company.sector               520
# company.type                  18
# demographics.age              76
# demographics.gender            3
# location.citizenship          73
# location.country code         74
# location.gdp                  81
# location.region                8
# wealth.type                    5
# wealth.worth in billions     183
# wealth.how.category            9
# wealth.how.from emerging       1
# wealth.how.industry           19
# wealth.how.inherited           6
# wealth.how.was founder         1
# wealth.how.was political       1
# dtype: int64

# %%
billion1_df['name'].nunique()
# Out:
# 2058

# %%
billion_df.nunique()
# Out:
# rank                    2595
# finalWorth              2595
# personName              2736
# source                   965
# industries                18
# countryOfCitizenship      70
# gender                     2
# lastName                1738
# estWorthPrev            2597
# dtype: int64

# %%
billion_df['personName'].nunique()
# Out:
# 2736

# %%
split_names = billion1_df.name.str.split().tolist()

# %%
for i, name in enumerate(split_names):
    if 'and' in name:
        
        print(i, name)
# Out:
# 6 ['Oeri', 'Hoffman', 'and', 'Sacher']
# 13 ['Theo', 'and', 'Karl', 'Albrecht']
# 15 ['Walter', 'Thomas', 'and', 'Raymond', 'Kwok']
# 24 ['Theo', 'and', 'Karl', 'Albrecht']
# 27 ['Hans', 'and', 'Gad', 'Rausing']
# 67 ['Walter', 'Thomas', 'and', 'Raymond', 'Kwok']
# 84 ['Robert', 'and', 'Ten', 'Fong', 'Ng']
# 208 ['James', 'Arthur', 'and', 'John', 'Irving']
# 260 ['Thomas', 'and', 'Raymond', 'Kwok']
# 266 ['Michael', 'and', 'Rainer', 'Schmidt-Ruthenbeck']
# 268 ['James', 'Arthur', 'and', 'John', 'Irving']
# 301 ['Jay', 'and', 'Arthur', 'Pritzker']
# 483 ['Adrian', 'and', 'John', 'Swire']
# 486 ['Joseph', 'and', 'Moise', 'Safra']
# 552 ['Michael', 'and', 'Rainer', 'Schmidt-Ruthenbeck']
# 782 ['Carlos', 'and', 'Alejandro', 'Bulgheroni']
# 805 ['Willi', 'and', 'Isolde', 'Liebherr']
# 826 ['Juan', 'and', 'Carlos', 'March']
# 906 ['Shashi', 'and', 'Ravi', 'Ruia']
# 913 ['Baldwin', 'and', 'Nikolaus', 'Knauf']
# 976 ['Roberto', 'and', 'Gabriel', 'Andrade']
# ...

# %%
for i, name in enumerate(split_names):
    if len(name) > 2: 
        newlist = [name[0],name[-1]]
        print (newlist)
# Out:
# ['Carlos', 'Helu']
# ['Oeri', 'Sacher']
# ['Lee', 'Kee']
# ['Theo', 'Albrecht']
# ['Walter', 'Kwok']
# ['Prince', 'Alsaud']
# ['Theo', 'Albrecht']
# ['S', 'Walton']
# ['Hans', 'Rausing']
# ['S.', 'Walton']
# ['Carlos', 'Helu']
# ['Anne', 'Chambers']
# ['Barbara', 'Anthony']
# ['Kwek', 'Beng']
# ['Walter', 'Kwok']
# ['Carlos', 'Helu']
# ['Lui', 'Woo']
# ['Robert', 'Ng']
# ['Prince', 'Alsaud']
# ['Antonio', 'Moraes']
# ['Eka', 'Widjaja']
# ['Jorge', 'Lemann']
# ['Lee', 'Kee']
# ['Mohamed', 'Mahfouz']
# ['Leonardo', 'Vecchio']
# ['S', 'Walton']
# ['Leonardo', 'Vecchio']
# ['Gerald', 'Grosvenor']
# ['Liem', 'Liong']
# ['Lee', 'Kee']
# ['Mustafa', 'Koc']
# ['Barbara', 'Anthony']
# ['Anne', 'Chambers']
# ['Anne', 'Chambers']
# ['Mohammad', 'Amoudi']
# ['Gregorio', 'Companc']
# ['German', 'Velasco']
# ['James', 'Irving']
# ['August', 'Finck']
# ['Luis', 'Sarmiento']
# ['Laurene', 'Jobs']
# ['Tiong', 'King']
# ['Dieter', 'Holtzbrinck']
# ['Quek', 'Chan']
# ['Gerald', 'Grosvenor']
# ...

# %%
billion1_df = pd.DataFrame(columns = ['First', 'Last'])
print(billion1_df)
# Out:
# Empty DataFrame
# Columns: [First, Last]
# Index: []
