# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahMason2015/Billionaires/blob/main/BillionairesData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
import sklearn as skl
import tensorflow as tf

# %%
latlng_df = pd.read_csv("../resources/LatLngCountriesBillionaires.csv")
latlng_df.head(10)
# Out:
#     latitude  longitude    country
# 0  28.033886   1.659626    Algeria
# 1        NaN        NaN     Angola
# 2        NaN        NaN  Argentina
# 3        NaN        NaN  Australia
# 4        NaN        NaN    Austria
# 5        NaN        NaN    Belgium
# 6        NaN        NaN     Brazil
# 7        NaN        NaN     Canada
# 8        NaN        NaN      Chile
# 9        NaN        NaN      China

# %%
billion_df = pd.read_csv("../resources/billionaires_dataset.csv")
billion_df.head()
# Out:
#    company.founded        company.name company.relationship company.sector  \
# 0             1975           Microsoft              founder       Software
# 1             1975           Microsoft              founder       Software
# 2             1975           Microsoft              founder       Software
# 3             1962  Berkshire Hathaway              founder        Finance
# 4             1962  Berkshire Hathaway              founder        Finance
#
#   company.type  demographics.age demographics.gender location.citizenship  \
# 0          new                40                male        United States
# 1          new                45                male        United States
# 2          new                58                male        United States
# 3          new                65                male        United States
# 4          new                70                male        United States
#
#   location.region  wealth.how.industry wealth.how.inherited
# 0   North America  Technology-Computer        not inherited
# 1   North America  Technology-Computer        not inherited
# 2   North America  Technology-Computer        not inherited
# 3   North America             Consumer        not inherited
# 4   North America             Consumer        not inherited

# %%
billion_df.rename(columns = {'location.citizenship': 'country'}, inplace = True)
billion_df.head()
# Out:
#    company.founded        company.name company.relationship company.sector  \
# 0             1975           Microsoft              founder       Software
# 1             1975           Microsoft              founder       Software
# 2             1975           Microsoft              founder       Software
# 3             1962  Berkshire Hathaway              founder        Finance
# 4             1962  Berkshire Hathaway              founder        Finance
#
#   company.type  demographics.age demographics.gender        country  \
# 0          new                40                male  United States
# 1          new                45                male  United States
# 2          new                58                male  United States
# 3          new                65                male  United States
# 4          new                70                male  United States
#
#   location.region  wealth.how.industry wealth.how.inherited
# 0   North America  Technology-Computer        not inherited
# 1   North America  Technology-Computer        not inherited
# 2   North America  Technology-Computer        not inherited
# 3   North America             Consumer        not inherited
# 4   North America             Consumer        not inherited

# %%
joined_df = pd.merge(billion_df, latlng_df, on=['country'])
joined_df.head()
# Out:
#    company.founded        company.name company.relationship company.sector  \
# 0             1975           Microsoft              founder       Software
# 1             1975           Microsoft              founder       Software
# 2             1975           Microsoft              founder       Software
# 3             1962  Berkshire Hathaway              founder        Finance
# 4             1962  Berkshire Hathaway              founder        Finance
#
#   company.type  demographics.age demographics.gender        country  \
# 0          new                40                male  United States
# 1          new                45                male  United States
# 2          new                58                male  United States
# 3          new                65                male  United States
# 4          new                70                male  United States
#
#   location.region  wealth.how.industry wealth.how.inherited  latitude  \
# 0   North America  Technology-Computer        not inherited  37.09024
# 1   North America  Technology-Computer        not inherited  37.09024
# 2   North America  Technology-Computer        not inherited  37.09024
# 3   North America             Consumer        not inherited  37.09024
# 4   North America             Consumer        not inherited  37.09024
#
#    longitude
# 0 -95.712891
# 1 -95.712891
# 2 -95.712891
# 3 -95.712891
# 4 -95.712891
